# %%
print("Welcome to python programming")
# Out:
# Welcome to python programming

# %%
# primitive data types - string str, integer int, floating point - float, boolean - bool

# %%
name = "manthan"

# %%
print(name)
# Out:
# manthan

# %%
name
# Out:
# 'manthan'

# %%
integer = 20
integer
# Out:
# 20

# %%
print("hello my name is", name)
# Out:
# hello my name is manthan

# %%
age = 20

# %%
print(f"hello my name is {name}")
print(f"my age is {age} years old")
# Out:
# hello my name is manthan
# my age is 20 years old

# %%
pizza = 20
eating_habit = "overeating"

# %%
print(f"i ate {pizza} pizza")
print(f"i am {eating_habit}")
# Out:
# i ate 20 pizza
# i am overeating

# %%
age = 20
salary = 2700.85
name = "manthan"
print(f"my age is {age} years old")
print(f"my salary is {salary}")
print(f"my name is {name}")
# Out:
# my age is 20 years old
# my salary is 2700.85
# my name is manthan

# %%
is_eligible = False
if is_eligible:
  print("you are eligible to vote")
else:
  print("not eligible")
# Out:
# not eligible

# %%
name = manthan
age = "20"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_906/1380781771.py in <cell line: 0>()
# ----> 1 name = manthan
#       2 age = "20"
#
# NameError: name 'manthan' is not defined

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age = int(age)
type(age)
# Out:
# int

# %%
num = 20.474
type(num)
# Out:
# float

# %%
num = int(num)
type(num)
# Out:
# int
